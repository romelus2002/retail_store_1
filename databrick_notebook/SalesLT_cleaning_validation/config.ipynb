# %%
# config notebook
BRONZE = "saleslt.bronze"
SILVER = "saleslt.silver"

TABLES = ["customer", "product", "sales_order_header", "sales_order_detail"]

active_views = {}

print("✓ Config loaded")
print(f"  Bronze : {BRONZE}")
print(f"  Silver : {SILVER}")
print(f"  Tables : {TABLES}")
