# %%
# Step 2 — Load Bronze
# %run /Workspace/Users/superromelus@gmail.com/project1/databrick_notebook/SalesLT_cleaning_validation/01_load_bronze

# %%
# Step 3 — Clean
# %run /Workspace/Users/superromelus@gmail.com/project1/databrick_notebook/SalesLT_cleaning_validation/02_clean_silver

# %%
# Step 4 — Validate
# %run /Workspace/Users/superromelus@gmail.com/project1/databrick_notebook/SalesLT_cleaning_validation/04_write_silver

# %%
# Step 5 — Write to Silver
# %run /Workspace/Users/superromelus@gmail.com/project1/databrick_notebook/SalesLT_cleaning_validation/04_write_silver
